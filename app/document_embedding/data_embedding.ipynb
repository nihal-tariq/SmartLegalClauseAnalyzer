# %%
import os
import glob
import json
import time
import pandas as pd

from dotenv import load_dotenv

from sqlalchemy import create_engine, Table, Column, Integer, String, MetaData

from langchain.schema import Document
from chromadb import PersistentClient
import chromadb
from chromadb.config import Settings
from langchain_huggingface import HuggingFaceEmbeddings

# %%
load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")

# %%
csv_folder = "legal_clause"

# %%
def load_csv_documents(csv_folder):
    documents = []
    for filepath in glob.glob(os.path.join(csv_folder, "*.csv")):
        df = pd.read_csv(filepath)
        file_name = os.path.basename(filepath)

        for idx, row in df.iterrows():
            content = "\n".join([f"{col}: {val}" for col, val in row.items()])
            metadata = {"source_file": file_name, "row_index": idx}
            documents.append(Document(page_content=content, metadata=metadata))

    print(f"✅ Loaded {len(documents)} documents from CSV files.")
    return documents

# %%
def save_documents(documents, folder="saved_docs"):
    os.makedirs(folder, exist_ok=True)

    with open(os.path.join(folder, "documents.json"), "w", encoding="utf-8") as f:
        json.dump(
            [{"content": doc.page_content, "metadata": doc.metadata} for doc in documents],
            f, indent=2
        )

    print(f"💾 Saved {len(documents)} documents to '{folder}/documents.json'")

# %%
def load_saved_documents(folder="saved_docs"):
    with open(os.path.join(folder, "documents.json"), "r", encoding="utf-8") as f:
        doc_data = json.load(f)

    documents = [Document(page_content=d["content"], metadata=d["metadata"]) for d in doc_data]
    print(f"✅ Loaded {len(documents)} documents from '{folder}/documents.json'")
    return documents

# %%
if not os.path.exists("saved_docs/documents.json"):
    documents = load_csv_documents(csv_folder)
    save_documents(documents)
else:
    documents = load_saved_documents()
# Out:
# ✅ Loaded 150881 documents from 'saved_docs/documents.json'

# %%
engine = create_engine(DATABASE_URL)
metadata_db = MetaData()

# %%
documents_table = Table(
    'legal_docs_metadata',
    metadata_db,
    Column('id', Integer, primary_key=True, autoincrement=True),
    Column('document_id', String, nullable=False),
    Column('chunk_text', String, nullable=False),
    Column('source', String, nullable=True),
    Column('row_index', Integer, nullable=True),
)

# %%
metadata_db.create_all(engine)

# %%
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

sample_vector = embedding_model.embed_query("Clause regarding employment period")
print(f"✅ Sample embedding vector size: {len(sample_vector)}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Sample embedding vector size: 768

# %%
# Initialize ChromaDB (Persistent)
persist_dir = "legal_chroma_db"
collection_name = "legal_index"

chroma_client = PersistentClient(path="legal_chroma_db")

vectorstore = chroma_client.get_or_create_collection(name="legal_index")


if collection_name in [c.name for c in chroma_client.list_collections()]:
    vectorstore = chroma_client.get_collection(name=collection_name)
    print(f"✅ Loaded existing ChromaDB collection.")
else:
    vectorstore = chroma_client.create_collection(name=collection_name)
    print(f"✅ Created new ChromaDB collection.")
# Out:
# ✅ Loaded existing ChromaDB collection.

# %%
BATCH_SIZE = 50
RETRY_LIMIT = 3
SLEEP_BETWEEN_RETRIES = 5  # seconds
CHECKPOINT_FILE = "embeddings_checkpoint.json"
VECTORSTORE_FOLDER = "chroma_vectorstore"

# %%
def save_checkpoint(processed_batches):
    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"processed_batches": list(processed_batches)}, f)


def load_checkpoint():
    if os.path.exists(CHECKPOINT_FILE):
        with open(CHECKPOINT_FILE, "r") as f:
            data = json.load(f)
            return set(data.get("processed_batches", []))  # Convert back to set
    return set()


# ✅ Batch Embedding and Storage with Metadata (using HuggingFaceEmbeddings)
def store_documents_in_batches(documents, source_file, embedding_model, vectorstore, chroma_client,
                               batch_size=BATCH_SIZE):
    total_docs = len(documents)
    processed_batches = load_checkpoint()
    successfully_stored_ids = []

    print(f"\n🚀 Starting embedding of {total_docs} documents in batches of {batch_size}...\n")

    for start_idx in range(0, total_docs, batch_size):
        batch_number = start_idx // batch_size

        if batch_number in processed_batches:
            print(f"⏩ Skipping already processed batch {batch_number}")
            continue

        batch_docs = documents[start_idx: start_idx + batch_size]
        batch_texts = [doc.page_content for doc in batch_docs]
        batch_metadatas = [doc.metadata for doc in batch_docs]
        batch_ids = [f"{source_file}_{start_idx + i}" for i in range(len(batch_docs))]

        success = False
        retry_count = 0

        while not success and retry_count < RETRY_LIMIT:
            try:
                start_time = time.time()

                # Embed documents
                batch_embeddings = embedding_model.embed_documents(batch_texts)

                # Store embeddings, metadata, and texts in vectorstore
                vectorstore.add(
                    ids=batch_ids,
                    embeddings=batch_embeddings,
                    documents=batch_texts,
                    metadatas=batch_metadatas
                )

                processed_batches.add(batch_number)
                save_checkpoint(processed_batches)

                successfully_stored_ids.extend(batch_ids)

                

                elapsed_time = round(time.time() - start_time, 2)
                print(
                    f"✅ Processed batch {batch_number} ({start_idx} to {start_idx + len(batch_docs) - 1}) in {elapsed_time} sec")

                success = True

            except Exception as e:
                retry_count += 1
                print(f"⚠️ Failed batch {batch_number} ({retry_count}/{RETRY_LIMIT} retries): {e}")
                time.sleep(SLEEP_BETWEEN_RETRIES)

        if not success:
            print(f"❌ Giving up on batch {batch_number} after {RETRY_LIMIT} retries.")

    chroma_client.persist()
    print("\n🎉 All documents embedded and stored successfully.")

    return {
        "processed_ids": successfully_stored_ids,
        "total_processed": len(successfully_stored_ids)
    }


result = store_documents_in_batches(
    documents=documents,
    source_file="legal_dataset",
    embedding_model=embedding_model,
    vectorstore=vectorstore,
    chroma_client=chroma_client
)

print(result["processed_ids"])  # List of successfully stored document IDs
print(result["total_processed"])  # Total count
# Out:
# 🚀 Starting embedding of 150881 documents in batches of 50...
#
# ⏩ Skipping already processed batch 0
# ⏩ Skipping already processed batch 1
# ⏩ Skipping already processed batch 2
# ⏩ Skipping already processed batch 3
# ⏩ Skipping already processed batch 4
# ⏩ Skipping already processed batch 5
# ⏩ Skipping already processed batch 6
# ⏩ Skipping already processed batch 7
# ⏩ Skipping already processed batch 8
# ⏩ Skipping already processed batch 9
# ⏩ Skipping already processed batch 10
# ⏩ Skipping already processed batch 11
# ⏩ Skipping already processed batch 12
# ⏩ Skipping already processed batch 13
# ⏩ Skipping already processed batch 14
# ⏩ Skipping already processed batch 15
# ⏩ Skipping already processed batch 16
# ⏩ Skipping already processed batch 17
# ⏩ Skipping already processed batch 18
# ⏩ Skipping already processed batch 19
# ⏩ Skipping already processed batch 20
# ⏩ Skipping already processed batch 21
# ⏩ Skipping already processed batch 22
# ⏩ Skipping already processed batch 23
# ⏩ Skipping already processed batch 24
# ⏩ Skipping already processed batch 25
# ⏩ Skipping already processed batch 26
# ⏩ Skipping already processed batch 27
# ⏩ Skipping already processed batch 28
# ⏩ Skipping already processed batch 29
# ⏩ Skipping already processed batch 30
# ⏩ Skipping already processed batch 31
# ⏩ Skipping already processed batch 32
# ⏩ Skipping already processed batch 33
# ⏩ Skipping already processed batch 34
# ⏩ Skipping already processed batch 35
# ⏩ Skipping already processed batch 36
# ⏩ Skipping already processed batch 37
# ⏩ Skipping already processed batch 38
# ⏩ Skipping already processed batch 39
# ⏩ Skipping already processed batch 40
# ⏩ Skipping already processed batch 41
# ⏩ Skipping already processed batch 42
# ⏩ Skipping already processed batch 43
# ⏩ Skipping already processed batch 44
# ⏩ Skipping already processed batch 45
# ⏩ Skipping already processed batch 46
# ⏩ Skipping already processed batch 47
# ⏩ Skipping already processed batch 48
# ⏩ Skipping already processed batch 49
# ⏩ Skipping already processed batch 50
# ⏩ Skipping already processed batch 51
# ⏩ Skipping already processed batch 52
# ⏩ Skipping already processed batch 53
# ⏩ Skipping already processed batch 54
# ⏩ Skipping already processed batch 55
# ⏩ Skipping already processed batch 56
# ⏩ Skipping already processed batch 57
# ⏩ Skipping already processed batch 58
# ⏩ Skipping already processed batch 59
# ⏩ Skipping already processed batch 60
# ⏩ Skipping already processed batch 61
# ⏩ Skipping already processed batch 62
# ⏩ Skipping already processed batch 63
# ⏩ Skipping already processed batch 64
# ⏩ Skipping already processed batch 65
# ⏩ Skipping already processed batch 66
# ⏩ Skipping already processed batch 67
# ⏩ Skipping already processed batch 68
# ⏩ Skipping already processed batch 69
# ⏩ Skipping already processed batch 70
# ⏩ Skipping already processed batch 71
# ⏩ Skipping already processed batch 72
# ⏩ Skipping already processed batch 73
# ⏩ Skipping already processed batch 74
# ⏩ Skipping already processed batch 75
# ⏩ Skipping already processed batch 76
# ⏩ Skipping already processed batch 77
# ⏩ Skipping already processed batch 78
# ⏩ Skipping already processed batch 79
# ⏩ Skipping already processed batch 80
# ⏩ Skipping already processed batch 81
# ⏩ Skipping already processed batch 82
# ⏩ Skipping already processed batch 83
# ⏩ Skipping already processed batch 84
# ⏩ Skipping already processed batch 85
# ⏩ Skipping already processed batch 86
# ⏩ Skipping already processed batch 87
# ⏩ Skipping already processed batch 88
# ⏩ Skipping already processed batch 89
# ⏩ Skipping already processed batch 90
# ⏩ Skipping already processed batch 91
# ⏩ Skipping already processed batch 92
# ⏩ Skipping already processed batch 93
# ⏩ Skipping already processed batch 94
# ⏩ Skipping already processed batch 95
# ⏩ Skipping already processed batch 96
# ⏩ Skipping already processed batch 97
# ⏩ Skipping already processed batch 98
# ⏩ Skipping already processed batch 99
# ⏩ Skipping already processed batch 100
# ⏩ Skipping already processed batch 101
# ⏩ Skipping already processed batch 102
# ⏩ Skipping already processed batch 103
# ⏩ Skipping already processed batch 104
# ⏩ Skipping already processed batch 105
# ⏩ Skipping already processed batch 106
# ⏩ Skipping already processed batch 107
# ⏩ Skipping already processed batch 108
# ⏩ Skipping already processed batch 109
# ⏩ Skipping already processed batch 110
# ⏩ Skipping already processed batch 111
# ⏩ Skipping already processed batch 112
# ⏩ Skipping already processed batch 113
# ⏩ Skipping already processed batch 114
# ⏩ Skipping already processed batch 115
# ⏩ Skipping already processed batch 116
# ⏩ Skipping already processed batch 117
# ⏩ Skipping already processed batch 118
# ⏩ Skipping already processed batch 119
# ⏩ Skipping already processed batch 120
# ⏩ Skipping already processed batch 121
# ⏩ Skipping already processed batch 122
# ⏩ Skipping already processed batch 123
# ⏩ Skipping already processed batch 124
# ⏩ Skipping already processed batch 125
# ⏩ Skipping already processed batch 126
# ⏩ Skipping already processed batch 127
# ⏩ Skipping already processed batch 128
# ⏩ Skipping already processed batch 129
# ⏩ Skipping already processed batch 130
# ⏩ Skipping already processed batch 131
# ⏩ Skipping already processed batch 132
# ⏩ Skipping already processed batch 133
# ⏩ Skipping already processed batch 134
# ⏩ Skipping already processed batch 135
# ⏩ Skipping already processed batch 136
# ⏩ Skipping already processed batch 137
# ⏩ Skipping already processed batch 138
# ⏩ Skipping already processed batch 139
# ⏩ Skipping already processed batch 140
# ⏩ Skipping already processed batch 141
# ⏩ Skipping already processed batch 142
# ⏩ Skipping already processed batch 143
# ⏩ Skipping already processed batch 144
# ⏩ Skipping already processed batch 145
# ⏩ Skipping already processed batch 146
# ⏩ Skipping already processed batch 147
# ⏩ Skipping already processed batch 148
# ⏩ Skipping already processed batch 149
# ⏩ Skipping already processed batch 150
# ⏩ Skipping already processed batch 151
# ⏩ Skipping already processed batch 152
# ⏩ Skipping already processed batch 153
# ⏩ Skipping already processed batch 154
# ⏩ Skipping already processed batch 155
# ⏩ Skipping already processed batch 156
# ⏩ Skipping already processed batch 157
# ⏩ Skipping already processed batch 158
# ⏩ Skipping already processed batch 159
# ⏩ Skipping already processed batch 160
# ⏩ Skipping already processed batch 161
# ⏩ Skipping already processed batch 162
# ⏩ Skipping already processed batch 163
# ⏩ Skipping already processed batch 164
# ⏩ Skipping already processed batch 165
# ⏩ Skipping already processed batch 166
# ⏩ Skipping already processed batch 167
# ⏩ Skipping already processed batch 168
# ⏩ Skipping already processed batch 169
# ⏩ Skipping already processed batch 170
# ⏩ Skipping already processed batch 171
# ⏩ Skipping already processed batch 172
# ⏩ Skipping already processed batch 173
# ⏩ Skipping already processed batch 174
# ⏩ Skipping already processed batch 175
# ⏩ Skipping already processed batch 176
# ⏩ Skipping already processed batch 177
# ⏩ Skipping already processed batch 178
# ⏩ Skipping already processed batch 179
# ⏩ Skipping already processed batch 180
# ⏩ Skipping already processed batch 181
# ⏩ Skipping already processed batch 182
# ⏩ Skipping already processed batch 183
# ⏩ Skipping already processed batch 184
# ⏩ Skipping already processed batch 185
# ⏩ Skipping already processed batch 186
# ⏩ Skipping already processed batch 187
# ⏩ Skipping already processed batch 188
# ⏩ Skipping already processed batch 189
# ⏩ Skipping already processed batch 190
# ⏩ Skipping already processed batch 191
# ⏩ Skipping already processed batch 192
# ⏩ Skipping already processed batch 193
# ⏩ Skipping already processed batch 194
# ⏩ Skipping already processed batch 195
# ⏩ Skipping already processed batch 196
# ⏩ Skipping already processed batch 197
# ⏩ Skipping already processed batch 198
# ⏩ Skipping already processed batch 199
# ⏩ Skipping already processed batch 200
# ⏩ Skipping already processed batch 201
# ⏩ Skipping already processed batch 202
# ⏩ Skipping already processed batch 203
# ⏩ Skipping already processed batch 204
# ⏩ Skipping already processed batch 205
# ⏩ Skipping already processed batch 206
# ⏩ Skipping already processed batch 207
# ⏩ Skipping already processed batch 208
# ⏩ Skipping already processed batch 209
# ⏩ Skipping already processed batch 210
# ⏩ Skipping already processed batch 211
# ⏩ Skipping already processed batch 212
# ⏩ Skipping already processed batch 213
# ⏩ Skipping already processed batch 214
# ⏩ Skipping already processed batch 215
# ⏩ Skipping already processed batch 216
# ⏩ Skipping already processed batch 217
# ⏩ Skipping already processed batch 218
# ⏩ Skipping already processed batch 219
# ⏩ Skipping already processed batch 220
# ⏩ Skipping already processed batch 221
# ⏩ Skipping already processed batch 222
# ⏩ Skipping already processed batch 223
# ⏩ Skipping already processed batch 224
# ⏩ Skipping already processed batch 225
# ⏩ Skipping already processed batch 226
# ⏩ Skipping already processed batch 227
# ⏩ Skipping already processed batch 228
# ⏩ Skipping already processed batch 229
# ⏩ Skipping already processed batch 230
# ⏩ Skipping already processed batch 231
# ⏩ Skipping already processed batch 232
# ⏩ Skipping already processed batch 233
# ⏩ Skipping already processed batch 234
# ⏩ Skipping already processed batch 235
# ⏩ Skipping already processed batch 236
# ⏩ Skipping already processed batch 237
# ⏩ Skipping already processed batch 238
# ⏩ Skipping already processed batch 239
# ⏩ Skipping already processed batch 240
# ⏩ Skipping already processed batch 241
# ⏩ Skipping already processed batch 242
# ⏩ Skipping already processed batch 243
# ⏩ Skipping already processed batch 244
# ⏩ Skipping already processed batch 245
# ⏩ Skipping already processed batch 246
# ⏩ Skipping already processed batch 247
# ⏩ Skipping already processed batch 248
# ⏩ Skipping already processed batch 249
# ⏩ Skipping already processed batch 250
# ⏩ Skipping already processed batch 251
# ⏩ Skipping already processed batch 252
# ⏩ Skipping already processed batch 253
# ⏩ Skipping already processed batch 254
# ⏩ Skipping already processed batch 255
# ⏩ Skipping already processed batch 256
# ⏩ Skipping already processed batch 257
# ⏩ Skipping already processed batch 258
# ⏩ Skipping already processed batch 259
# ⏩ Skipping already processed batch 260
# ⏩ Skipping already processed batch 261
# ⏩ Skipping already processed batch 262
# ⏩ Skipping already processed batch 263
# ⏩ Skipping already processed batch 264
# ⏩ Skipping already processed batch 265
# ⏩ Skipping already processed batch 266
# ⏩ Skipping already processed batch 267
# ⏩ Skipping already processed batch 268
# ⏩ Skipping already processed batch 269
# ⏩ Skipping already processed batch 270
# ⏩ Skipping already processed batch 271
# ⏩ Skipping already processed batch 272
# ⏩ Skipping already processed batch 273
# ⏩ Skipping already processed batch 274
# ⏩ Skipping already processed batch 275
# ⏩ Skipping already processed batch 276
# ⏩ Skipping already processed batch 277
# ⏩ Skipping already processed batch 278
# ⏩ Skipping already processed batch 279
# ⏩ Skipping already processed batch 280
# ⏩ Skipping already processed batch 281
# ⏩ Skipping already processed batch 282
# ⏩ Skipping already processed batch 283
# ⏩ Skipping already processed batch 284
# ⏩ Skipping already processed batch 285
# ⏩ Skipping already processed batch 286
# ⏩ Skipping already processed batch 287
# ⏩ Skipping already processed batch 288
# ⏩ Skipping already processed batch 289
# ⏩ Skipping already processed batch 290
# ⏩ Skipping already processed batch 291
# ⏩ Skipping already processed batch 292
# ⏩ Skipping already processed batch 293
# ⏩ Skipping already processed batch 294
# ⏩ Skipping already processed batch 295
# ⏩ Skipping already processed batch 296
# ⏩ Skipping already processed batch 297
# ⏩ Skipping already processed batch 298
# ⏩ Skipping already processed batch 299
# ⏩ Skipping already processed batch 300
# ⏩ Skipping already processed batch 301
# ⏩ Skipping already processed batch 302
# ⏩ Skipping already processed batch 303
# ⏩ Skipping already processed batch 304
# ⏩ Skipping already processed batch 305
# ⏩ Skipping already processed batch 306
# ⏩ Skipping already processed batch 307
# ⏩ Skipping already processed batch 308
# ⏩ Skipping already processed batch 309
# ⏩ Skipping already processed batch 310
# ⏩ Skipping already processed batch 311
# ⏩ Skipping already processed batch 312
# ⏩ Skipping already processed batch 313
# ⏩ Skipping already processed batch 314
# ⏩ Skipping already processed batch 315
# ⏩ Skipping already processed batch 316
# ⏩ Skipping already processed batch 317
# ⏩ Skipping already processed batch 318
# ⏩ Skipping already processed batch 319
# ⏩ Skipping already processed batch 320
# ⏩ Skipping already processed batch 321
# ⏩ Skipping already processed batch 322
# ⏩ Skipping already processed batch 323
# ⏩ Skipping already processed batch 324
# ⏩ Skipping already processed batch 325
# ⏩ Skipping already processed batch 326
# ⏩ Skipping already processed batch 327
# ⏩ Skipping already processed batch 328
# ⏩ Skipping already processed batch 329
# ⏩ Skipping already processed batch 330
# ⏩ Skipping already processed batch 331
# ⏩ Skipping already processed batch 332
# ⏩ Skipping already processed batch 333
# ⏩ Skipping already processed batch 334
# ⏩ Skipping already processed batch 335
# ⏩ Skipping already processed batch 336
# ⏩ Skipping already processed batch 337
# ⏩ Skipping already processed batch 338
# ⏩ Skipping already processed batch 339
# ⏩ Skipping already processed batch 340
# ⏩ Skipping already processed batch 341
# ⏩ Skipping already processed batch 342
# ⏩ Skipping already processed batch 343
# ⏩ Skipping already processed batch 344
# ⏩ Skipping already processed batch 345
# ⏩ Skipping already processed batch 346
# ⏩ Skipping already processed batch 347
# ⏩ Skipping already processed batch 348
# ⏩ Skipping already processed batch 349
# ⏩ Skipping already processed batch 350
# ⏩ Skipping already processed batch 351
# ⏩ Skipping already processed batch 352
# ⏩ Skipping already processed batch 353
# ⏩ Skipping already processed batch 354
# ⏩ Skipping already processed batch 355
# ⏩ Skipping already processed batch 356
# ⏩ Skipping already processed batch 357
# ⏩ Skipping already processed batch 358
# ⏩ Skipping already processed batch 359
# ⏩ Skipping already processed batch 360
# ⏩ Skipping already processed batch 361
# ⏩ Skipping already processed batch 362
# ⏩ Skipping already processed batch 363
# ⏩ Skipping already processed batch 364
# ⏩ Skipping already processed batch 365
# ⏩ Skipping already processed batch 366
# ⏩ Skipping already processed batch 367
# ⏩ Skipping already processed batch 368
# ⏩ Skipping already processed batch 369
# ⏩ Skipping already processed batch 370
# ⏩ Skipping already processed batch 371
# ⏩ Skipping already processed batch 372
# ⏩ Skipping already processed batch 373
# ⏩ Skipping already processed batch 374
# ⏩ Skipping already processed batch 375
# ⏩ Skipping already processed batch 376
# ⏩ Skipping already processed batch 377
# ⏩ Skipping already processed batch 378
# ⏩ Skipping already processed batch 379
# ⏩ Skipping already processed batch 380
# ⏩ Skipping already processed batch 381
# ⏩ Skipping already processed batch 382
# ⏩ Skipping already processed batch 383
# ⏩ Skipping already processed batch 384
# ⏩ Skipping already processed batch 385
# ⏩ Skipping already processed batch 386
# ⏩ Skipping already processed batch 387
# ⏩ Skipping already processed batch 388
# ⏩ Skipping already processed batch 389
# ⏩ Skipping already processed batch 390
# ⏩ Skipping already processed batch 391
# ⏩ Skipping already processed batch 392
# ⏩ Skipping already processed batch 393
# ⏩ Skipping already processed batch 394
# ⏩ Skipping already processed batch 395
# ⏩ Skipping already processed batch 396
# ⏩ Skipping already processed batch 397
# ⏩ Skipping already processed batch 398
# ⏩ Skipping already processed batch 399
# ⏩ Skipping already processed batch 400
# ⏩ Skipping already processed batch 401
# ⏩ Skipping already processed batch 402
# ⏩ Skipping already processed batch 403
# ⏩ Skipping already processed batch 404
# ⏩ Skipping already processed batch 405
# ⏩ Skipping already processed batch 406
# ⏩ Skipping already processed batch 407
# ⏩ Skipping already processed batch 408
# ⏩ Skipping already processed batch 409
# ⏩ Skipping already processed batch 410
# ⏩ Skipping already processed batch 411
# ⏩ Skipping already processed batch 412
# ⏩ Skipping already processed batch 413
# ⏩ Skipping already processed batch 414
# ⏩ Skipping already processed batch 415
# ⏩ Skipping already processed batch 416
# ⏩ Skipping already processed batch 417
# ⏩ Skipping already processed batch 418
# ⏩ Skipping already processed batch 419
# ⏩ Skipping already processed batch 420
# ⏩ Skipping already processed batch 421
# ⏩ Skipping already processed batch 422
# ⏩ Skipping already processed batch 423
# ⏩ Skipping already processed batch 424
# ⏩ Skipping already processed batch 425
# ⏩ Skipping already processed batch 426
# ⏩ Skipping already processed batch 427
# ⏩ Skipping already processed batch 428
# ⏩ Skipping already processed batch 429
# ⏩ Skipping already processed batch 430
# ⏩ Skipping already processed batch 431
# ⏩ Skipping already processed batch 432
# ⏩ Skipping already processed batch 433
# ⏩ Skipping already processed batch 434
# ⏩ Skipping already processed batch 435
# ⏩ Skipping already processed batch 436
# ⏩ Skipping already processed batch 437
# ⏩ Skipping already processed batch 438
# ⏩ Skipping already processed batch 439
# ⏩ Skipping already processed batch 440
# ⏩ Skipping already processed batch 441
# ⏩ Skipping already processed batch 442
# ⏩ Skipping already processed batch 443
# ⏩ Skipping already processed batch 444
# ⏩ Skipping already processed batch 445
# ⏩ Skipping already processed batch 446
# ⏩ Skipping already processed batch 447
# ⏩ Skipping already processed batch 448
# ⏩ Skipping already processed batch 449
# ⏩ Skipping already processed batch 450
# ⏩ Skipping already processed batch 451
# ⏩ Skipping already processed batch 452
# ⏩ Skipping already processed batch 453
# ⏩ Skipping already processed batch 454
# ⏩ Skipping already processed batch 455
# ⏩ Skipping already processed batch 456
# ⏩ Skipping already processed batch 457
# ⏩ Skipping already processed batch 458
# ⏩ Skipping already processed batch 459
# ⏩ Skipping already processed batch 460
# ⏩ Skipping already processed batch 461
# ⏩ Skipping already processed batch 462
# ⏩ Skipping already processed batch 463
# ⏩ Skipping already processed batch 464
# ⏩ Skipping already processed batch 465
# ⏩ Skipping already processed batch 466
# ⏩ Skipping already processed batch 467
# ⏩ Skipping already processed batch 468
# ⏩ Skipping already processed batch 469
# ⏩ Skipping already processed batch 470
# ⏩ Skipping already processed batch 471
# ⏩ Skipping already processed batch 472
# ⏩ Skipping already processed batch 473
# ⏩ Skipping already processed batch 474
# ⏩ Skipping already processed batch 475
# ⏩ Skipping already processed batch 476
# ⏩ Skipping already processed batch 477
# ⏩ Skipping already processed batch 478
# ⏩ Skipping already processed batch 479
# ⏩ Skipping already processed batch 480
# ⏩ Skipping already processed batch 481
# ⏩ Skipping already processed batch 482
# ⏩ Skipping already processed batch 483
# ⏩ Skipping already processed batch 484
# ⏩ Skipping already processed batch 485
# ⏩ Skipping already processed batch 486
# ⏩ Skipping already processed batch 487
# ⏩ Skipping already processed batch 488
# ⏩ Skipping already processed batch 489
# ⏩ Skipping already processed batch 490
# ⏩ Skipping already processed batch 491
# ⏩ Skipping already processed batch 492
# ⏩ Skipping already processed batch 493
# ⏩ Skipping already processed batch 494
# ⏩ Skipping already processed batch 495
# ⏩ Skipping already processed batch 496
# ⏩ Skipping already processed batch 497
# ⏩ Skipping already processed batch 498
# ⏩ Skipping already processed batch 499
# ⏩ Skipping already processed batch 500
# ⏩ Skipping already processed batch 501
# ⏩ Skipping already processed batch 502
# ⏩ Skipping already processed batch 503
# ⏩ Skipping already processed batch 504
# ⏩ Skipping already processed batch 505
# ⏩ Skipping already processed batch 506
# ⏩ Skipping already processed batch 507
# ⏩ Skipping already processed batch 508
# ⏩ Skipping already processed batch 509
# ⏩ Skipping already processed batch 510
# ⏩ Skipping already processed batch 511
# ⏩ Skipping already processed batch 512
# ⏩ Skipping already processed batch 513
# ⏩ Skipping already processed batch 514
# ⏩ Skipping already processed batch 515
# ⏩ Skipping already processed batch 516
# ⏩ Skipping already processed batch 517
# ⏩ Skipping already processed batch 518
# ⏩ Skipping already processed batch 519
# ⏩ Skipping already processed batch 520
# ⏩ Skipping already processed batch 521
# ⏩ Skipping already processed batch 522
# ⏩ Skipping already processed batch 523
# ⏩ Skipping already processed batch 524
# ⏩ Skipping already processed batch 525
# ⏩ Skipping already processed batch 526
# ⏩ Skipping already processed batch 527
# ⏩ Skipping already processed batch 528
# ⏩ Skipping already processed batch 529
# ⏩ Skipping already processed batch 530
# ⏩ Skipping already processed batch 531
# ⏩ Skipping already processed batch 532
# ⏩ Skipping already processed batch 533
# ⏩ Skipping already processed batch 534
# ⏩ Skipping already processed batch 535
# ⏩ Skipping already processed batch 536
# ⏩ Skipping already processed batch 537
# ⏩ Skipping already processed batch 538
# ⏩ Skipping already processed batch 539
# ⏩ Skipping already processed batch 540
# ⏩ Skipping already processed batch 541
# ⏩ Skipping already processed batch 542
# ⏩ Skipping already processed batch 543
# ⏩ Skipping already processed batch 544
# ⏩ Skipping already processed batch 545
# ⏩ Skipping already processed batch 546
# ⏩ Skipping already processed batch 547
# ⏩ Skipping already processed batch 548
# ⏩ Skipping already processed batch 549
# ⏩ Skipping already processed batch 550
# ⏩ Skipping already processed batch 551
# ⏩ Skipping already processed batch 552
# ⏩ Skipping already processed batch 553
# ⏩ Skipping already processed batch 554
# ⏩ Skipping already processed batch 555
# ⏩ Skipping already processed batch 556
# ⏩ Skipping already processed batch 557
# ⏩ Skipping already processed batch 558
# ⏩ Skipping already processed batch 559
# ⏩ Skipping already processed batch 560
# ⏩ Skipping already processed batch 561
# ⏩ Skipping already processed batch 562
# ⏩ Skipping already processed batch 563
# ⏩ Skipping already processed batch 564
# ⏩ Skipping already processed batch 565
# ⏩ Skipping already processed batch 566
# ⏩ Skipping already processed batch 567
# ⏩ Skipping already processed batch 568
# ⏩ Skipping already processed batch 569
# ⏩ Skipping already processed batch 570
# ⏩ Skipping already processed batch 571
# ⏩ Skipping already processed batch 572
# ⏩ Skipping already processed batch 573
# ⏩ Skipping already processed batch 574
# ⏩ Skipping already processed batch 575
# ⏩ Skipping already processed batch 576
# ⏩ Skipping already processed batch 577
# ⏩ Skipping already processed batch 578
# ⏩ Skipping already processed batch 579
# ⏩ Skipping already processed batch 580
# ⏩ Skipping already processed batch 581
# ⏩ Skipping already processed batch 582
# ⏩ Skipping already processed batch 583
# ⏩ Skipping already processed batch 584
# ⏩ Skipping already processed batch 585
# ⏩ Skipping already processed batch 586
# ⏩ Skipping already processed batch 587
# ⏩ Skipping already processed batch 588
# ⏩ Skipping already processed batch 589
# ⏩ Skipping already processed batch 590
# ⏩ Skipping already processed batch 591
# ⏩ Skipping already processed batch 592
# ⏩ Skipping already processed batch 593
# ⏩ Skipping already processed batch 594
# ⏩ Skipping already processed batch 595
# ⏩ Skipping already processed batch 596
# ⏩ Skipping already processed batch 597
# ⏩ Skipping already processed batch 598
# ⏩ Skipping already processed batch 599
# ⏩ Skipping already processed batch 600
# ⏩ Skipping already processed batch 601
# ⏩ Skipping already processed batch 602
# ⏩ Skipping already processed batch 603
# ⏩ Skipping already processed batch 604
# ⏩ Skipping already processed batch 605
# ⏩ Skipping already processed batch 606
# ⏩ Skipping already processed batch 607
# ⏩ Skipping already processed batch 608
# ⏩ Skipping already processed batch 609
# ⏩ Skipping already processed batch 610
# ⏩ Skipping already processed batch 611
# ⏩ Skipping already processed batch 612
# ⏩ Skipping already processed batch 613
# ⏩ Skipping already processed batch 614
# ⏩ Skipping already processed batch 615
# ⏩ Skipping already processed batch 616
# ⏩ Skipping already processed batch 617
# ⏩ Skipping already processed batch 618
# ⏩ Skipping already processed batch 619
# ⏩ Skipping already processed batch 620
# ⏩ Skipping already processed batch 621
# ⏩ Skipping already processed batch 622
# ⏩ Skipping already processed batch 623
# ⏩ Skipping already processed batch 624
# ⏩ Skipping already processed batch 625
# ⏩ Skipping already processed batch 626
# ⏩ Skipping already processed batch 627
# ⏩ Skipping already processed batch 628
# ⏩ Skipping already processed batch 629
# ⏩ Skipping already processed batch 630
# ⏩ Skipping already processed batch 631
# ⏩ Skipping already processed batch 632
# ⏩ Skipping already processed batch 633
# ⏩ Skipping already processed batch 634
# ⏩ Skipping already processed batch 635
# ⏩ Skipping already processed batch 636
# ⏩ Skipping already processed batch 637
# ⏩ Skipping already processed batch 638
# ⏩ Skipping already processed batch 639
# ⏩ Skipping already processed batch 640
# ⏩ Skipping already processed batch 641
# ⏩ Skipping already processed batch 642
# ⏩ Skipping already processed batch 643
# ⏩ Skipping already processed batch 644
# ⏩ Skipping already processed batch 645
# ⏩ Skipping already processed batch 646
# ⏩ Skipping already processed batch 647
# ⏩ Skipping already processed batch 648
# ⏩ Skipping already processed batch 649
# ⏩ Skipping already processed batch 650
# ⏩ Skipping already processed batch 651
# ⏩ Skipping already processed batch 652
# ⏩ Skipping already processed batch 653
# ⏩ Skipping already processed batch 654
# ⏩ Skipping already processed batch 655
# ⏩ Skipping already processed batch 656
# ⏩ Skipping already processed batch 657
# ⏩ Skipping already processed batch 658
# ⏩ Skipping already processed batch 659
# ⏩ Skipping already processed batch 660
# ⏩ Skipping already processed batch 661
# ⏩ Skipping already processed batch 662
# ⏩ Skipping already processed batch 663
# ⏩ Skipping already processed batch 664
# ⏩ Skipping already processed batch 665
# ⏩ Skipping already processed batch 666
# ⏩ Skipping already processed batch 667
# ⏩ Skipping already processed batch 668
# ⏩ Skipping already processed batch 669
# ⏩ Skipping already processed batch 670
# ⏩ Skipping already processed batch 671
# ⏩ Skipping already processed batch 672
# ⏩ Skipping already processed batch 673
# ⏩ Skipping already processed batch 674
# ⏩ Skipping already processed batch 675
# ⏩ Skipping already processed batch 676
# ⏩ Skipping already processed batch 677
# ⏩ Skipping already processed batch 678
# ⏩ Skipping already processed batch 679
# ⏩ Skipping already processed batch 680
# ⏩ Skipping already processed batch 681
# ⏩ Skipping already processed batch 682
# ⏩ Skipping already processed batch 683
# ⏩ Skipping already processed batch 684
# ⏩ Skipping already processed batch 685
# ⏩ Skipping already processed batch 686
# ⏩ Skipping already processed batch 687
# ⏩ Skipping already processed batch 688
# ⏩ Skipping already processed batch 689
# ⏩ Skipping already processed batch 690
# ⏩ Skipping already processed batch 691
# ⏩ Skipping already processed batch 692
# ⏩ Skipping already processed batch 693
# ⏩ Skipping already processed batch 694
# ⏩ Skipping already processed batch 695
# ⏩ Skipping already processed batch 696
# ⏩ Skipping already processed batch 697
# ⏩ Skipping already processed batch 698
# ⏩ Skipping already processed batch 699
# ⏩ Skipping already processed batch 700
# ⏩ Skipping already processed batch 701
# ⏩ Skipping already processed batch 702
# ⏩ Skipping already processed batch 703
# ⏩ Skipping already processed batch 704
# ⏩ Skipping already processed batch 705
# ⏩ Skipping already processed batch 706
# ⏩ Skipping already processed batch 707
# ⏩ Skipping already processed batch 708
# ⏩ Skipping already processed batch 709
# ⏩ Skipping already processed batch 710
# ⏩ Skipping already processed batch 711
# ⏩ Skipping already processed batch 712
# ⏩ Skipping already processed batch 713
# ⏩ Skipping already processed batch 714
# ⏩ Skipping already processed batch 715
# ⏩ Skipping already processed batch 716
# ⏩ Skipping already processed batch 717
# ⏩ Skipping already processed batch 718
# ⏩ Skipping already processed batch 719
# ⏩ Skipping already processed batch 720
# ⏩ Skipping already processed batch 721
# ⏩ Skipping already processed batch 722
# ⏩ Skipping already processed batch 723
# ⏩ Skipping already processed batch 724
# ⏩ Skipping already processed batch 725
# ⏩ Skipping already processed batch 726
# ⏩ Skipping already processed batch 727
# ⏩ Skipping already processed batch 728
# ⏩ Skipping already processed batch 729
# ⏩ Skipping already processed batch 730
# ⏩ Skipping already processed batch 731
# ⏩ Skipping already processed batch 732
# ⏩ Skipping already processed batch 733
# ⏩ Skipping already processed batch 734
# ⏩ Skipping already processed batch 735
# ⏩ Skipping already processed batch 736
# ⏩ Skipping already processed batch 737
# ⏩ Skipping already processed batch 738
# ⏩ Skipping already processed batch 739
# ⏩ Skipping already processed batch 740
# ⏩ Skipping already processed batch 741
# ⏩ Skipping already processed batch 742
# ⏩ Skipping already processed batch 743
# ⏩ Skipping already processed batch 744
# ⏩ Skipping already processed batch 745
# ⏩ Skipping already processed batch 746
# ⏩ Skipping already processed batch 747
# ⏩ Skipping already processed batch 748
# ⏩ Skipping already processed batch 749
# ⏩ Skipping already processed batch 750
# ⏩ Skipping already processed batch 751
# ⏩ Skipping already processed batch 752
# ⏩ Skipping already processed batch 753
# ⏩ Skipping already processed batch 754
# ⏩ Skipping already processed batch 755
# ⏩ Skipping already processed batch 756
# ⏩ Skipping already processed batch 757
# ⏩ Skipping already processed batch 758
# ⏩ Skipping already processed batch 759
# ⏩ Skipping already processed batch 760
# ⏩ Skipping already processed batch 761
# ⏩ Skipping already processed batch 762
# ⏩ Skipping already processed batch 763
# ⏩ Skipping already processed batch 764
# ⏩ Skipping already processed batch 765
# ⏩ Skipping already processed batch 766
# ⏩ Skipping already processed batch 767
# ⏩ Skipping already processed batch 768
# ⏩ Skipping already processed batch 769
# ⏩ Skipping already processed batch 770
# ⏩ Skipping already processed batch 771
# ⏩ Skipping already processed batch 772
# ⏩ Skipping already processed batch 773
# ⏩ Skipping already processed batch 774
# ⏩ Skipping already processed batch 775
# ⏩ Skipping already processed batch 776
# ⏩ Skipping already processed batch 777
# ⏩ Skipping already processed batch 778
# ⏩ Skipping already processed batch 779
# ⏩ Skipping already processed batch 780
# ⏩ Skipping already processed batch 781
# ⏩ Skipping already processed batch 782
# ⏩ Skipping already processed batch 783
# ⏩ Skipping already processed batch 784
# ⏩ Skipping already processed batch 785
# ⏩ Skipping already processed batch 786
# ⏩ Skipping already processed batch 787
# ⏩ Skipping already processed batch 788
# ⏩ Skipping already processed batch 789
# ⏩ Skipping already processed batch 790
# ⏩ Skipping already processed batch 791
# ⏩ Skipping already processed batch 792
# ⏩ Skipping already processed batch 793
# ⏩ Skipping already processed batch 794
# ⏩ Skipping already processed batch 795
# ⏩ Skipping already processed batch 796
# ⏩ Skipping already processed batch 797
# ⏩ Skipping already processed batch 798
# ⏩ Skipping already processed batch 799
# ⏩ Skipping already processed batch 800
# ⏩ Skipping already processed batch 801
# ⏩ Skipping already processed batch 802
# ⏩ Skipping already processed batch 803
# ⏩ Skipping already processed batch 804
# ⏩ Skipping already processed batch 805
# ⏩ Skipping already processed batch 806
# ⏩ Skipping already processed batch 807
# ⏩ Skipping already processed batch 808
# ⏩ Skipping already processed batch 809
# ⏩ Skipping already processed batch 810
# ⏩ Skipping already processed batch 811
# ⏩ Skipping already processed batch 812
# ⏩ Skipping already processed batch 813
# ⏩ Skipping already processed batch 814
# ⏩ Skipping already processed batch 815
# ⏩ Skipping already processed batch 816
# ⏩ Skipping already processed batch 817
# ⏩ Skipping already processed batch 818
# ⏩ Skipping already processed batch 819
# ⏩ Skipping already processed batch 820
# ⏩ Skipping already processed batch 821
# ⏩ Skipping already processed batch 822
# ⏩ Skipping already processed batch 823
# ⏩ Skipping already processed batch 824
# ⏩ Skipping already processed batch 825
# ⏩ Skipping already processed batch 826
# ⏩ Skipping already processed batch 827
# ⏩ Skipping already processed batch 828
# ⏩ Skipping already processed batch 829
# ⏩ Skipping already processed batch 830
# ⏩ Skipping already processed batch 831
# ⏩ Skipping already processed batch 832
# ⏩ Skipping already processed batch 833
# ⏩ Skipping already processed batch 834
# ⏩ Skipping already processed batch 835
# ⏩ Skipping already processed batch 836
# ⏩ Skipping already processed batch 837
# ⏩ Skipping already processed batch 838
# ⏩ Skipping already processed batch 839
# ⏩ Skipping already processed batch 840
# ⏩ Skipping already processed batch 841
# ⏩ Skipping already processed batch 842
# ⏩ Skipping already processed batch 843
# ⏩ Skipping already processed batch 844
# ⏩ Skipping already processed batch 845
# ⏩ Skipping already processed batch 846
# ⏩ Skipping already processed batch 847
# ⏩ Skipping already processed batch 848
# ⏩ Skipping already processed batch 849
# ⏩ Skipping already processed batch 850
# ⏩ Skipping already processed batch 851
# ⏩ Skipping already processed batch 852
# ⏩ Skipping already processed batch 853
# ⏩ Skipping already processed batch 854
# ⏩ Skipping already processed batch 855
# ⏩ Skipping already processed batch 856
# ⏩ Skipping already processed batch 857
# ⏩ Skipping already processed batch 858
# ⏩ Skipping already processed batch 859
# ⏩ Skipping already processed batch 860
# ⏩ Skipping already processed batch 861
# ⏩ Skipping already processed batch 862
# ⏩ Skipping already processed batch 863
# ⏩ Skipping already processed batch 864
# ⏩ Skipping already processed batch 865
# ⏩ Skipping already processed batch 866
# ⏩ Skipping already processed batch 867
# ⏩ Skipping already processed batch 868
# ⏩ Skipping already processed batch 869
# ⏩ Skipping already processed batch 870
# ⏩ Skipping already processed batch 871
# ⏩ Skipping already processed batch 872
# ⏩ Skipping already processed batch 873
# ⏩ Skipping already processed batch 874
# ⏩ Skipping already processed batch 875
# ⏩ Skipping already processed batch 876
# ⏩ Skipping already processed batch 877
# ⏩ Skipping already processed batch 878
# ⏩ Skipping already processed batch 879
# ⏩ Skipping already processed batch 880
# ⏩ Skipping already processed batch 881
# ⏩ Skipping already processed batch 882
# ⏩ Skipping already processed batch 883
# ⏩ Skipping already processed batch 884
# ⏩ Skipping already processed batch 885
# ⏩ Skipping already processed batch 886
# ⏩ Skipping already processed batch 887
# ⏩ Skipping already processed batch 888
# ⏩ Skipping already processed batch 889
# ⏩ Skipping already processed batch 890
# ⏩ Skipping already processed batch 891
# ⏩ Skipping already processed batch 892
# ⏩ Skipping already processed batch 893
# ⏩ Skipping already processed batch 894
# ⏩ Skipping already processed batch 895
# ⏩ Skipping already processed batch 896
# ⏩ Skipping already processed batch 897
# ⏩ Skipping already processed batch 898
# ⏩ Skipping already processed batch 899
# ⏩ Skipping already processed batch 900
# ⏩ Skipping already processed batch 901
# ⏩ Skipping already processed batch 902
# ⏩ Skipping already processed batch 903
# ⏩ Skipping already processed batch 904
# ⏩ Skipping already processed batch 905
# ⏩ Skipping already processed batch 906
# ⏩ Skipping already processed batch 907
# ⏩ Skipping already processed batch 908
# ⏩ Skipping already processed batch 909
# ⏩ Skipping already processed batch 910
# ⏩ Skipping already processed batch 911
# ⏩ Skipping already processed batch 912
# ⏩ Skipping already processed batch 913
# ⏩ Skipping already processed batch 914
# ⏩ Skipping already processed batch 915
# ⏩ Skipping already processed batch 916
# ⏩ Skipping already processed batch 917
# ⏩ Skipping already processed batch 918
# ⏩ Skipping already processed batch 919
# ⏩ Skipping already processed batch 920
# ⏩ Skipping already processed batch 921
# ⏩ Skipping already processed batch 922
# ⏩ Skipping already processed batch 923
# ⏩ Skipping already processed batch 924
# ⏩ Skipping already processed batch 925
# ⏩ Skipping already processed batch 926
# ⏩ Skipping already processed batch 927
# ⏩ Skipping already processed batch 928
# ⏩ Skipping already processed batch 929
# ⏩ Skipping already processed batch 930
# ⏩ Skipping already processed batch 931
# ⏩ Skipping already processed batch 932
# ⏩ Skipping already processed batch 933
# ⏩ Skipping already processed batch 934
# ⏩ Skipping already processed batch 935
# ⏩ Skipping already processed batch 936
# ⏩ Skipping already processed batch 937
# ⏩ Skipping already processed batch 938
# ⏩ Skipping already processed batch 939
# ⏩ Skipping already processed batch 940
# ⏩ Skipping already processed batch 941
# ⏩ Skipping already processed batch 942
# ⏩ Skipping already processed batch 943
# ⏩ Skipping already processed batch 944
# ⏩ Skipping already processed batch 945
# ⏩ Skipping already processed batch 946
# ⏩ Skipping already processed batch 947
# ⏩ Skipping already processed batch 948
# ⏩ Skipping already processed batch 949
# ⏩ Skipping already processed batch 950
# ⏩ Skipping already processed batch 951
# ⏩ Skipping already processed batch 952
# ⏩ Skipping already processed batch 953
# ⏩ Skipping already processed batch 954
# ⏩ Skipping already processed batch 955
# ⏩ Skipping already processed batch 956
# ⏩ Skipping already processed batch 957
# ⏩ Skipping already processed batch 958
# ⏩ Skipping already processed batch 959
# ⏩ Skipping already processed batch 960
# ⏩ Skipping already processed batch 961
# ⏩ Skipping already processed batch 962
# ⏩ Skipping already processed batch 963
# ⏩ Skipping already processed batch 964
# ⏩ Skipping already processed batch 965
# ⏩ Skipping already processed batch 966
# ⏩ Skipping already processed batch 967
# ⏩ Skipping already processed batch 968
# ⏩ Skipping already processed batch 969
# ⏩ Skipping already processed batch 970
# ⏩ Skipping already processed batch 971
# ⏩ Skipping already processed batch 972
# ⏩ Skipping already processed batch 973
# ⏩ Skipping already processed batch 974
# ⏩ Skipping already processed batch 975
# ⏩ Skipping already processed batch 976
# ⏩ Skipping already processed batch 977
# ⏩ Skipping already processed batch 978
# ⏩ Skipping already processed batch 979
# ⏩ Skipping already processed batch 980
# ⏩ Skipping already processed batch 981
# ⏩ Skipping already processed batch 982
# ⏩ Skipping already processed batch 983
# ⏩ Skipping already processed batch 984
# ⏩ Skipping already processed batch 985
# ⏩ Skipping already processed batch 986
# ⏩ Skipping already processed batch 987
# ⏩ Skipping already processed batch 988
# ⏩ Skipping already processed batch 989
# ⏩ Skipping already processed batch 990
# ⏩ Skipping already processed batch 991
# ⏩ Skipping already processed batch 992
# ⏩ Skipping already processed batch 993
# ⏩ Skipping already processed batch 994
# ⏩ Skipping already processed batch 995
# ⏩ Skipping already processed batch 996
# ⏩ Skipping already processed batch 997
# ⏩ Skipping already processed batch 998
# ⏩ Skipping already processed batch 999
# ⏩ Skipping already processed batch 1000
# ⏩ Skipping already processed batch 1001
# ⏩ Skipping already processed batch 1002
# ⏩ Skipping already processed batch 1003
# ⏩ Skipping already processed batch 1004
# ⏩ Skipping already processed batch 1005
# ⏩ Skipping already processed batch 1006
# ⏩ Skipping already processed batch 1007
# ⏩ Skipping already processed batch 1008
# ⏩ Skipping already processed batch 1009
# ⏩ Skipping already processed batch 1010
# ⏩ Skipping already processed batch 1011
# ⏩ Skipping already processed batch 1012
# ⏩ Skipping already processed batch 1013
# ⏩ Skipping already processed batch 1014
# ⏩ Skipping already processed batch 1015
# ⏩ Skipping already processed batch 1016
# ⏩ Skipping already processed batch 1017
# ⏩ Skipping already processed batch 1018
# ⏩ Skipping already processed batch 1019
# ⏩ Skipping already processed batch 1020
# ⏩ Skipping already processed batch 1021
# ⏩ Skipping already processed batch 1022
# ⏩ Skipping already processed batch 1023
# ⏩ Skipping already processed batch 1024
# ⏩ Skipping already processed batch 1025
# ⏩ Skipping already processed batch 1026
# ⏩ Skipping already processed batch 1027
# ⏩ Skipping already processed batch 1028
# ⏩ Skipping already processed batch 1029
# ⏩ Skipping already processed batch 1030
# ⏩ Skipping already processed batch 1031
# ⏩ Skipping already processed batch 1032
# ⏩ Skipping already processed batch 1033
# ⏩ Skipping already processed batch 1034
# ⏩ Skipping already processed batch 1035
# ⏩ Skipping already processed batch 1036
# ⏩ Skipping already processed batch 1037
# ⏩ Skipping already processed batch 1038
# ⏩ Skipping already processed batch 1039
# ⏩ Skipping already processed batch 1040
# ⏩ Skipping already processed batch 1041
# ⏩ Skipping already processed batch 1042
# ⏩ Skipping already processed batch 1043
# ⏩ Skipping already processed batch 1044
# ⏩ Skipping already processed batch 1045
# ⏩ Skipping already processed batch 1046
# ⏩ Skipping already processed batch 1047
# ⏩ Skipping already processed batch 1048
# ⏩ Skipping already processed batch 1049
# ⏩ Skipping already processed batch 1050
# ⏩ Skipping already processed batch 1051
# ⏩ Skipping already processed batch 1052
# ⏩ Skipping already processed batch 1053
# ⏩ Skipping already processed batch 1054
# ⏩ Skipping already processed batch 1055
# ⏩ Skipping already processed batch 1056
# ⏩ Skipping already processed batch 1057
# ⏩ Skipping already processed batch 1058
# ⏩ Skipping already processed batch 1059
# ⏩ Skipping already processed batch 1060
# ⏩ Skipping already processed batch 1061
# ⏩ Skipping already processed batch 1062
# ⏩ Skipping already processed batch 1063
# ⏩ Skipping already processed batch 1064
# ⏩ Skipping already processed batch 1065
# ⏩ Skipping already processed batch 1066
# ⏩ Skipping already processed batch 1067
# ⏩ Skipping already processed batch 1068
# ⏩ Skipping already processed batch 1069
# ⏩ Skipping already processed batch 1070
# ⏩ Skipping already processed batch 1071
# ⏩ Skipping already processed batch 1072
# ⏩ Skipping already processed batch 1073
# ⏩ Skipping already processed batch 1074
# ⏩ Skipping already processed batch 1075
# ⏩ Skipping already processed batch 1076
# ⏩ Skipping already processed batch 1077
# ⏩ Skipping already processed batch 1078
# ⏩ Skipping already processed batch 1079
# ⏩ Skipping already processed batch 1080
# ⏩ Skipping already processed batch 1081
# ⏩ Skipping already processed batch 1082
# ⏩ Skipping already processed batch 1083
# ⏩ Skipping already processed batch 1084
# ⏩ Skipping already processed batch 1085
# ⏩ Skipping already processed batch 1086
# ⏩ Skipping already processed batch 1087
# ⏩ Skipping already processed batch 1088
# ⏩ Skipping already processed batch 1089
# ⏩ Skipping already processed batch 1090
# ⏩ Skipping already processed batch 1091
# ⏩ Skipping already processed batch 1092
# ⏩ Skipping already processed batch 1093
# ⏩ Skipping already processed batch 1094
# ⏩ Skipping already processed batch 1095
# ⏩ Skipping already processed batch 1096
# ⏩ Skipping already processed batch 1097
# ⏩ Skipping already processed batch 1098
# ⏩ Skipping already processed batch 1099
# ⏩ Skipping already processed batch 1100
# ⏩ Skipping already processed batch 1101
# ⏩ Skipping already processed batch 1102
# ⏩ Skipping already processed batch 1103
# ⏩ Skipping already processed batch 1104
# ⏩ Skipping already processed batch 1105
# ⏩ Skipping already processed batch 1106
# ⏩ Skipping already processed batch 1107
# ⏩ Skipping already processed batch 1108
# ⏩ Skipping already processed batch 1109
# ⏩ Skipping already processed batch 1110
# ⏩ Skipping already processed batch 1111
# ⏩ Skipping already processed batch 1112
# ⏩ Skipping already processed batch 1113
# ⏩ Skipping already processed batch 1114
# ⏩ Skipping already processed batch 1115
# ⏩ Skipping already processed batch 1116
# ⏩ Skipping already processed batch 1117
# ⏩ Skipping already processed batch 1118
# ⏩ Skipping already processed batch 1119
# ⏩ Skipping already processed batch 1120
# ⏩ Skipping already processed batch 1121
# ⏩ Skipping already processed batch 1122
# ⏩ Skipping already processed batch 1123
# ⏩ Skipping already processed batch 1124
# ⏩ Skipping already processed batch 1125
# ⏩ Skipping already processed batch 1126
# ⏩ Skipping already processed batch 1127
# ⏩ Skipping already processed batch 1128
# ⏩ Skipping already processed batch 1129
# ⏩ Skipping already processed batch 1130
# ⏩ Skipping already processed batch 1131
# ⏩ Skipping already processed batch 1132
# ⏩ Skipping already processed batch 1133
# ⏩ Skipping already processed batch 1134
# ⏩ Skipping already processed batch 1135
# ⏩ Skipping already processed batch 1136
# ⏩ Skipping already processed batch 1137
# ⏩ Skipping already processed batch 1138
# ⏩ Skipping already processed batch 1139
# ⏩ Skipping already processed batch 1140
# ⏩ Skipping already processed batch 1141
# ⏩ Skipping already processed batch 1142
# ⏩ Skipping already processed batch 1143
# ⏩ Skipping already processed batch 1144
# ⏩ Skipping already processed batch 1145
# ⏩ Skipping already processed batch 1146
# ⏩ Skipping already processed batch 1147
# ⏩ Skipping already processed batch 1148
# ⏩ Skipping already processed batch 1149
# ⏩ Skipping already processed batch 1150
# ⏩ Skipping already processed batch 1151
# ⏩ Skipping already processed batch 1152
# ⏩ Skipping already processed batch 1153
# ⏩ Skipping already processed batch 1154
# ⏩ Skipping already processed batch 1155
# ⏩ Skipping already processed batch 1156
# ⏩ Skipping already processed batch 1157
# ⏩ Skipping already processed batch 1158
# ⏩ Skipping already processed batch 1159
# ⏩ Skipping already processed batch 1160
# ⏩ Skipping already processed batch 1161
# ⏩ Skipping already processed batch 1162
# ⏩ Skipping already processed batch 1163
# ⏩ Skipping already processed batch 1164
# ⏩ Skipping already processed batch 1165
# ⏩ Skipping already processed batch 1166
# ⏩ Skipping already processed batch 1167
# ⏩ Skipping already processed batch 1168
# ⏩ Skipping already processed batch 1169
# ⏩ Skipping already processed batch 1170
# ⏩ Skipping already processed batch 1171
# ⏩ Skipping already processed batch 1172
# ⏩ Skipping already processed batch 1173
# ⏩ Skipping already processed batch 1174
# ⏩ Skipping already processed batch 1175
# ⏩ Skipping already processed batch 1176
# ⏩ Skipping already processed batch 1177
# ⏩ Skipping already processed batch 1178
# ⏩ Skipping already processed batch 1179
# ⏩ Skipping already processed batch 1180
# ⏩ Skipping already processed batch 1181
# ⏩ Skipping already processed batch 1182
# ⏩ Skipping already processed batch 1183
# ⏩ Skipping already processed batch 1184
# ⏩ Skipping already processed batch 1185
# ⏩ Skipping already processed batch 1186
# ⏩ Skipping already processed batch 1187
# ⏩ Skipping already processed batch 1188
# ⏩ Skipping already processed batch 1189
# ⏩ Skipping already processed batch 1190
# ⏩ Skipping already processed batch 1191
# ⏩ Skipping already processed batch 1192
# ⏩ Skipping already processed batch 1193
# ⏩ Skipping already processed batch 1194
# ⏩ Skipping already processed batch 1195
# ⏩ Skipping already processed batch 1196
# ⏩ Skipping already processed batch 1197
# ⏩ Skipping already processed batch 1198
# ⏩ Skipping already processed batch 1199
# ⏩ Skipping already processed batch 1200
# ⏩ Skipping already processed batch 1201
# ⏩ Skipping already processed batch 1202
# ⏩ Skipping already processed batch 1203
# ⏩ Skipping already processed batch 1204
# ⏩ Skipping already processed batch 1205
# ⏩ Skipping already processed batch 1206
# ⏩ Skipping already processed batch 1207
# ⏩ Skipping already processed batch 1208
# ⏩ Skipping already processed batch 1209
# ⏩ Skipping already processed batch 1210
# ⏩ Skipping already processed batch 1211
# ⏩ Skipping already processed batch 1212
# ⏩ Skipping already processed batch 1213
# ⏩ Skipping already processed batch 1214
# ⏩ Skipping already processed batch 1215
# ⏩ Skipping already processed batch 1216
# ⏩ Skipping already processed batch 1217
# ⏩ Skipping already processed batch 1218
# ⏩ Skipping already processed batch 1219
# ⏩ Skipping already processed batch 1220
# ⏩ Skipping already processed batch 1221
# ⏩ Skipping already processed batch 1222
# ⏩ Skipping already processed batch 1223
# ⏩ Skipping already processed batch 1224
# ⏩ Skipping already processed batch 1225
# ...
# ⏩ Skipping already processed batch 2652
# ⏩ Skipping already processed batch 2653
# ⏩ Skipping already processed batch 2654
# ⏩ Skipping already processed batch 2655
# ⏩ Skipping already processed batch 2656
# ⏩ Skipping already processed batch 2657
# ⏩ Skipping already processed batch 2658
# ⏩ Skipping already processed batch 2659
# ⏩ Skipping already processed batch 2660
# ⏩ Skipping already processed batch 2661
# ⏩ Skipping already processed batch 2662
# ⏩ Skipping already processed batch 2663
# ⏩ Skipping already processed batch 2664
# ⏩ Skipping already processed batch 2665
# ⏩ Skipping already processed batch 2666
# ⏩ Skipping already processed batch 2667
# ⏩ Skipping already processed batch 2668
# ⏩ Skipping already processed batch 2669
# ⏩ Skipping already processed batch 2670
# ⏩ Skipping already processed batch 2671
# ⏩ Skipping already processed batch 2672
# ⏩ Skipping already processed batch 2673
# ⏩ Skipping already processed batch 2674
# ⏩ Skipping already processed batch 2675
# ⏩ Skipping already processed batch 2676
# ⏩ Skipping already processed batch 2677
# ⏩ Skipping already processed batch 2678
# ⏩ Skipping already processed batch 2679
# ⏩ Skipping already processed batch 2680
# ⏩ Skipping already processed batch 2681
# ⏩ Skipping already processed batch 2682
# ⏩ Skipping already processed batch 2683
# ⏩ Skipping already processed batch 2684
# ⏩ Skipping already processed batch 2685
# ⏩ Skipping already processed batch 2686
# ⏩ Skipping already processed batch 2687
# ⏩ Skipping already processed batch 2688
# ⏩ Skipping already processed batch 2689
# ⏩ Skipping already processed batch 2690
# ⏩ Skipping already processed batch 2691
# ⏩ Skipping already processed batch 2692
# ⏩ Skipping already processed batch 2693
# ⏩ Skipping already processed batch 2694
# ⏩ Skipping already processed batch 2695
# ⏩ Skipping already processed batch 2696
# ⏩ Skipping already processed batch 2697
# ⏩ Skipping already processed batch 2698
# ⏩ Skipping already processed batch 2699
# ⏩ Skipping already processed batch 2700
# ⏩ Skipping already processed batch 2701
# ⏩ Skipping already processed batch 2702
# ⏩ Skipping already processed batch 2703
# ⏩ Skipping already processed batch 2704
# ⏩ Skipping already processed batch 2705
# ⏩ Skipping already processed batch 2706
# ⏩ Skipping already processed batch 2707
# ⏩ Skipping already processed batch 2708
# ⏩ Skipping already processed batch 2709
# ⏩ Skipping already processed batch 2710
# ⏩ Skipping already processed batch 2711
# ⏩ Skipping already processed batch 2712
# ⏩ Skipping already processed batch 2713
# ⏩ Skipping already processed batch 2714
# ⏩ Skipping already processed batch 2715
# ⏩ Skipping already processed batch 2716
# ⏩ Skipping already processed batch 2717
# ⏩ Skipping already processed batch 2718
# ⏩ Skipping already processed batch 2719
# ⏩ Skipping already processed batch 2720
# ⏩ Skipping already processed batch 2721
# ⏩ Skipping already processed batch 2722
# ⏩ Skipping already processed batch 2723
# ⏩ Skipping already processed batch 2724
# ⏩ Skipping already processed batch 2725
# ⏩ Skipping already processed batch 2726
# ⏩ Skipping already processed batch 2727
# ⏩ Skipping already processed batch 2728
# ⏩ Skipping already processed batch 2729
# ⏩ Skipping already processed batch 2730
# ⏩ Skipping already processed batch 2731
# ⏩ Skipping already processed batch 2732
# ⏩ Skipping already processed batch 2733
# ⏩ Skipping already processed batch 2734
# ⏩ Skipping already processed batch 2735
# ⏩ Skipping already processed batch 2736
# ⏩ Skipping already processed batch 2737
# ⏩ Skipping already processed batch 2738
# ⏩ Skipping already processed batch 2739
# ⏩ Skipping already processed batch 2740
# ⏩ Skipping already processed batch 2741
# ⏩ Skipping already processed batch 2742
# ⏩ Skipping already processed batch 2743
# ⏩ Skipping already processed batch 2744
# ⏩ Skipping already processed batch 2745
# ⏩ Skipping already processed batch 2746
# ⏩ Skipping already processed batch 2747
# ⏩ Skipping already processed batch 2748
# ⏩ Skipping already processed batch 2749
# ⏩ Skipping already processed batch 2750
# ⏩ Skipping already processed batch 2751
# ⏩ Skipping already processed batch 2752
# ⏩ Skipping already processed batch 2753
# ⏩ Skipping already processed batch 2754
# ⏩ Skipping already processed batch 2755
# ⏩ Skipping already processed batch 2756
# ⏩ Skipping already processed batch 2757
# ⏩ Skipping already processed batch 2758
# ⏩ Skipping already processed batch 2759
# ⏩ Skipping already processed batch 2760
# ⏩ Skipping already processed batch 2761
# ⏩ Skipping already processed batch 2762
# ⏩ Skipping already processed batch 2763
# ⏩ Skipping already processed batch 2764
# ⏩ Skipping already processed batch 2765
# ⏩ Skipping already processed batch 2766
# ⏩ Skipping already processed batch 2767
# ⏩ Skipping already processed batch 2768
# ⏩ Skipping already processed batch 2769
# ⏩ Skipping already processed batch 2770
# ⏩ Skipping already processed batch 2771
# ⏩ Skipping already processed batch 2772
# ⏩ Skipping already processed batch 2773
# ⏩ Skipping already processed batch 2774
# ⏩ Skipping already processed batch 2775
# ⏩ Skipping already processed batch 2776
# ⏩ Skipping already processed batch 2777
# ⏩ Skipping already processed batch 2778
# ⏩ Skipping already processed batch 2779
# ⏩ Skipping already processed batch 2780
# ⏩ Skipping already processed batch 2781
# ⏩ Skipping already processed batch 2782
# ⏩ Skipping already processed batch 2783
# ⏩ Skipping already processed batch 2784
# ⏩ Skipping already processed batch 2785
# ⏩ Skipping already processed batch 2786
# ⏩ Skipping already processed batch 2787
# ⏩ Skipping already processed batch 2788
# ⏩ Skipping already processed batch 2789
# ⏩ Skipping already processed batch 2790
# ⏩ Skipping already processed batch 2791
# ⏩ Skipping already processed batch 2792
# ⏩ Skipping already processed batch 2793
# ⏩ Skipping already processed batch 2794
# ⏩ Skipping already processed batch 2795
# ⏩ Skipping already processed batch 2796
# ⏩ Skipping already processed batch 2797
# ⏩ Skipping already processed batch 2798
# ⏩ Skipping already processed batch 2799
# ⏩ Skipping already processed batch 2800
# ⏩ Skipping already processed batch 2801
# ⏩ Skipping already processed batch 2802
# ⏩ Skipping already processed batch 2803
# ⏩ Skipping already processed batch 2804
# ⏩ Skipping already processed batch 2805
# ⏩ Skipping already processed batch 2806
# ⏩ Skipping already processed batch 2807
# ⏩ Skipping already processed batch 2808
# ⏩ Skipping already processed batch 2809
# ⏩ Skipping already processed batch 2810
# ⏩ Skipping already processed batch 2811
# ⏩ Skipping already processed batch 2812
# ⏩ Skipping already processed batch 2813
# ⏩ Skipping already processed batch 2814
# ⏩ Skipping already processed batch 2815
# ⏩ Skipping already processed batch 2816
# ⏩ Skipping already processed batch 2817
# ⏩ Skipping already processed batch 2818
# ⏩ Skipping already processed batch 2819
# ⏩ Skipping already processed batch 2820
# ⏩ Skipping already processed batch 2821
# ⏩ Skipping already processed batch 2822
# ⏩ Skipping already processed batch 2823
# ⏩ Skipping already processed batch 2824
# ⏩ Skipping already processed batch 2825
# ⏩ Skipping already processed batch 2826
# ⏩ Skipping already processed batch 2827
# ⏩ Skipping already processed batch 2828
# ⏩ Skipping already processed batch 2829
# ⏩ Skipping already processed batch 2830
# ⏩ Skipping already processed batch 2831
# ⏩ Skipping already processed batch 2832
# ⏩ Skipping already processed batch 2833
# ⏩ Skipping already processed batch 2834
# ⏩ Skipping already processed batch 2835
# ⏩ Skipping already processed batch 2836
# ⏩ Skipping already processed batch 2837
# ⏩ Skipping already processed batch 2838
# ⏩ Skipping already processed batch 2839
# ⏩ Skipping already processed batch 2840
# ⏩ Skipping already processed batch 2841
# ⏩ Skipping already processed batch 2842
# ⏩ Skipping already processed batch 2843
# ⏩ Skipping already processed batch 2844
# ⏩ Skipping already processed batch 2845
# ⏩ Skipping already processed batch 2846
# ⏩ Skipping already processed batch 2847
# ⏩ Skipping already processed batch 2848
# ⏩ Skipping already processed batch 2849
# ⏩ Skipping already processed batch 2850
# ⏩ Skipping already processed batch 2851
# ⏩ Skipping already processed batch 2852
# ⏩ Skipping already processed batch 2853
# ⏩ Skipping already processed batch 2854
# ⏩ Skipping already processed batch 2855
# ⏩ Skipping already processed batch 2856
# ⏩ Skipping already processed batch 2857
# ⏩ Skipping already processed batch 2858
# ⏩ Skipping already processed batch 2859
# ⏩ Skipping already processed batch 2860
# ⏩ Skipping already processed batch 2861
# ⏩ Skipping already processed batch 2862
# ⏩ Skipping already processed batch 2863
# ⏩ Skipping already processed batch 2864
# ⏩ Skipping already processed batch 2865
# ⏩ Skipping already processed batch 2866
# ⏩ Skipping already processed batch 2867
# ⏩ Skipping already processed batch 2868
# ⏩ Skipping already processed batch 2869
# ⏩ Skipping already processed batch 2870
# ⏩ Skipping already processed batch 2871
# ⏩ Skipping already processed batch 2872
# ⏩ Skipping already processed batch 2873
# ⏩ Skipping already processed batch 2874
# ⏩ Skipping already processed batch 2875
# ⏩ Skipping already processed batch 2876
# ⏩ Skipping already processed batch 2877
# ⏩ Skipping already processed batch 2878
# ⏩ Skipping already processed batch 2879
# ⏩ Skipping already processed batch 2880
# ⏩ Skipping already processed batch 2881
# ⏩ Skipping already processed batch 2882
# ⏩ Skipping already processed batch 2883
# ⏩ Skipping already processed batch 2884
# ⏩ Skipping already processed batch 2885
# ⏩ Skipping already processed batch 2886
# ⏩ Skipping already processed batch 2887
# ⏩ Skipping already processed batch 2888
# ⏩ Skipping already processed batch 2889
# ⏩ Skipping already processed batch 2890
# ⏩ Skipping already processed batch 2891
# ⏩ Skipping already processed batch 2892
# ⏩ Skipping already processed batch 2893
# ⏩ Skipping already processed batch 2894
# ⏩ Skipping already processed batch 2895
# ⏩ Skipping already processed batch 2896
# ⏩ Skipping already processed batch 2897
# ⏩ Skipping already processed batch 2898
# ⏩ Skipping already processed batch 2899
# ⏩ Skipping already processed batch 2900
# ⏩ Skipping already processed batch 2901
# ⏩ Skipping already processed batch 2902
# ⏩ Skipping already processed batch 2903
# ⏩ Skipping already processed batch 2904
# ⏩ Skipping already processed batch 2905
# ⏩ Skipping already processed batch 2906
# ⏩ Skipping already processed batch 2907
# ⏩ Skipping already processed batch 2908
# ⏩ Skipping already processed batch 2909
# ⏩ Skipping already processed batch 2910
# ⏩ Skipping already processed batch 2911
# ⏩ Skipping already processed batch 2912
# ⏩ Skipping already processed batch 2913
# ⏩ Skipping already processed batch 2914
# ⏩ Skipping already processed batch 2915
# ⏩ Skipping already processed batch 2916
# ⏩ Skipping already processed batch 2917
# ⏩ Skipping already processed batch 2918
# ⏩ Skipping already processed batch 2919
# ⏩ Skipping already processed batch 2920
# ⏩ Skipping already processed batch 2921
# ⏩ Skipping already processed batch 2922
# ⏩ Skipping already processed batch 2923
# ⏩ Skipping already processed batch 2924
# ⏩ Skipping already processed batch 2925
# ⏩ Skipping already processed batch 2926
# ⏩ Skipping already processed batch 2927
# ⏩ Skipping already processed batch 2928
# ⏩ Skipping already processed batch 2929
# ⏩ Skipping already processed batch 2930
# ⏩ Skipping already processed batch 2931
# ⏩ Skipping already processed batch 2932
# ⏩ Skipping already processed batch 2933
# ⏩ Skipping already processed batch 2934
# ⏩ Skipping already processed batch 2935
# ⏩ Skipping already processed batch 2936
# ⏩ Skipping already processed batch 2937
# ⏩ Skipping already processed batch 2938
# ⏩ Skipping already processed batch 2939
# ⏩ Skipping already processed batch 2940
# ⏩ Skipping already processed batch 2941
# ⏩ Skipping already processed batch 2942
# ⏩ Skipping already processed batch 2943
# ⏩ Skipping already processed batch 2944
# ⏩ Skipping already processed batch 2945
# ⏩ Skipping already processed batch 2946
# ⏩ Skipping already processed batch 2947
# ⏩ Skipping already processed batch 2948
# ⏩ Skipping already processed batch 2949
# ⏩ Skipping already processed batch 2950
# ⏩ Skipping already processed batch 2951
# ⏩ Skipping already processed batch 2952
# ⏩ Skipping already processed batch 2953
# ⏩ Skipping already processed batch 2954
# ⏩ Skipping already processed batch 2955
# ⏩ Skipping already processed batch 2956
# ⏩ Skipping already processed batch 2957
# ⏩ Skipping already processed batch 2958
# ⏩ Skipping already processed batch 2959
# ⏩ Skipping already processed batch 2960
# ⏩ Skipping already processed batch 2961
# ⏩ Skipping already processed batch 2962
# ⏩ Skipping already processed batch 2963
# ⏩ Skipping already processed batch 2964
# ⏩ Skipping already processed batch 2965
# ⏩ Skipping already processed batch 2966
# ⏩ Skipping already processed batch 2967
# ⏩ Skipping already processed batch 2968
# ⏩ Skipping already processed batch 2969
# ⏩ Skipping already processed batch 2970
# ⏩ Skipping already processed batch 2971
# ⏩ Skipping already processed batch 2972
# ⏩ Skipping already processed batch 2973
# ⏩ Skipping already processed batch 2974
# ⏩ Skipping already processed batch 2975
# ⏩ Skipping already processed batch 2976
# ⏩ Skipping already processed batch 2977
# ⏩ Skipping already processed batch 2978
# ⏩ Skipping already processed batch 2979
# ⏩ Skipping already processed batch 2980
# ⏩ Skipping already processed batch 2981
# ⏩ Skipping already processed batch 2982
# ⏩ Skipping already processed batch 2983
# ⏩ Skipping already processed batch 2984
# ⏩ Skipping already processed batch 2985
# ⏩ Skipping already processed batch 2986
# ⏩ Skipping already processed batch 2987
# ⏩ Skipping already processed batch 2988
# ⏩ Skipping already processed batch 2989
# ⏩ Skipping already processed batch 2990
# ⏩ Skipping already processed batch 2991
# ⏩ Skipping already processed batch 2992
# ⏩ Skipping already processed batch 2993
# ⏩ Skipping already processed batch 2994
# ⏩ Skipping already processed batch 2995
# ⏩ Skipping already processed batch 2996
# ⏩ Skipping already processed batch 2997
# ⏩ Skipping already processed batch 2998
# ⏩ Skipping already processed batch 2999
# ⏩ Skipping already processed batch 3000
# ⏩ Skipping already processed batch 3001
# ⏩ Skipping already processed batch 3002
# ⏩ Skipping already processed batch 3003
# ⏩ Skipping already processed batch 3004
# ⏩ Skipping already processed batch 3005
# ⏩ Skipping already processed batch 3006
# ⏩ Skipping already processed batch 3007
# ⏩ Skipping already processed batch 3008
# ⏩ Skipping already processed batch 3009
# ⏩ Skipping already processed batch 3010
# ⏩ Skipping already processed batch 3011
# ⏩ Skipping already processed batch 3012
# ⏩ Skipping already processed batch 3013
# ⏩ Skipping already processed batch 3014
# ⏩ Skipping already processed batch 3015
# ⏩ Skipping already processed batch 3016
# ⏩ Skipping already processed batch 3017
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 83
#      75     print("\n🎉 All documents embedded and stored successfully.")
#      77     return {
#      78         "processed_ids": successfully_stored_ids,
#      79         "total_processed": len(successfully_stored_ids)
#      80     }
# ---> 83 result = store_documents_in_batches(
#      84     documents=documents,
#      85     source_file="legal_dataset",
#      86     embedding_model=embedding_model,
#      87     vectorstore=vectorstore,
#      88     chroma_client=chroma_client
#      89 )
#      91 print(result["processed_ids"])  # List of successfully stored document IDs
#      92 print(result["total_processed"])  # Total count
#
# Cell In[18], line 74, in store_documents_in_batches(documents, source_file, embedding_model, vectorstore, chroma_client, batch_size)
#      71     if not success:
#      72         print(f"❌ Giving up on batch {batch_number} after {RETRY_LIMIT} retries.")
# ---> 74 chroma_client.persist()
#      75 print("\n🎉 All documents embedded and stored successfully.")
#      77 return {
#      78     "processed_ids": successfully_stored_ids,
#      79     "total_processed": len(successfully_stored_ids)
#      80 }
#
# AttributeError: 'Client' object has no attribute 'persist'

# %%
vector_collection = chroma_client.get_collection(name = "legal_index")
print(vector_collection)
# Out:
# Collection(name=legal_index)

# %%
from chromadb import Client
from chromadb.config import Settings

# Set the path where your Chroma DB is stored
persist_directory = "legal_chroma_db"

# Create a client connected to the persisted DB
client = Client(Settings(persist_directory=persist_directory, chroma_db_impl="duckdb+parquet"))

# List all collections
collections = client.list_collections()

for col in collections:
    print(col.name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 8
#       5 persist_directory = "legal_chroma_db"
#       7 # Create a client connected to the persisted DB
# ----> 8 client = Client(Settings(persist_directory=persist_directory, chroma_db_impl="duckdb+parquet"))
#      10 # List all collections
#      11 collections = client.list_collections()
#
# File ~\PycharmProjects\SmartLegalClauseAnalyzer\.venv\Lib\site-packages\chromadb\__init__.py:379, in Client(settings, tenant, database)
#     376 tenant = str(tenant)
#     377 database = str(database)
# --> 379 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File ~\PycharmProjects\SmartLegalClauseAnalyzer\.venv\Lib\site-packages\chromadb\api\client.py:65, in Client.__init__(self, tenant, database, settings)
#      59 def __init__(
#      60     self,
#      61     tenant: str = DEFAULT_TENANT,
#      62     database: str = DEFAULT_DATABASE,
#      63     settings: Settings = Settings(),
#      64 ) -> None:
# ---> 65     super().__init__(settings=settings)
#      66     self.tenant = tenant
#      67     self.database = database
#
# File ~\PycharmProjects\SmartLegalClauseAnalyzer\.venv\Lib\site-packages\chromadb\api\shared_system_client.py:19, in SharedSystemClient.__init__(self, settings)
#      14 def __init__(
#      15     self,
#      16     settings: Settings = Settings(),
#      17 ) -> None:
#      18     self._identifier = SharedSystemClient._get_identifier_from_settings(settings)
# ---> 19     SharedSystemClient._create_system_if_not_exists(self._identifier, settings)
#
# File ~\PycharmProjects\SmartLegalClauseAnalyzer\.venv\Lib\site-packages\chromadb\api\shared_system_client.py:26, in SharedSystemClient._create_system_if_not_exists(cls, identifier, settings)
#      21 @classmethod
#      22 def _create_system_if_not_exists(
#      23     cls, identifier: str, settings: Settings
#      24 ) -> System:
#      25     if identifier not in cls._identifier_to_system:
# ---> 26         new_system = System(settings)
#      27         cls._identifier_to_system[identifier] = new_system
#      29         new_system.instance(ProductTelemetryClient)
#
# File ~\PycharmProjects\SmartLegalClauseAnalyzer\.venv\Lib\site-packages\chromadb\config.py:385, in System.__init__(self, settings)
#     383 # Validate settings don't contain any legacy config values
#     384 for key in _legacy_config_keys:
# --> 385     if settings[key] is not None:
#     386         raise ValueError(LEGACY_ERROR)
#     388 if (
#     389     settings["chroma_segment_cache_policy"] is not None
#     390     and settings["chroma_segment_cache_policy"] != "LRU"
#     391 ):
#
# File ~\PycharmProjects\SmartLegalClauseAnalyzer\.venv\Lib\site-packages\chromadb\config.py:319, in Settings.__getitem__(self, key)
#     317 # Error on legacy config values
#     318 if isinstance(val, str) and val in _legacy_config_values:
# --> 319     raise ValueError(LEGACY_ERROR)
#     320 return val
#
# ValueError: You are using a deprecated configuration of Chroma.
#
# If you do not have data you wish to migrate, you only need to change how you construct
# your Chroma client. Please see the "New Clients" section of https://docs.trychroma.com/deployment/migration.
# ________________________________________________________________________________________________
#
# If you do have data you wish to migrate, we have a migration tool you can use in order to
# migrate your data to the new Chroma architecture.
# Please `pip install chroma-migrate` and run `chroma-migrate` to migrate your data and then
# change how you construct your Chroma client.
#
# See https://docs.trychroma.com/deployment/migration for more information or join our discord at https://discord.gg/MMeYNTmh3x for help!

# %%
import chromadb
from chromadb.config import Settings

# Path to your persisted Chroma DB directory
PERSIST_DIR = "legal_chroma_db"

# Initialize Chroma client
client = chromadb.PersistentClient(path=PERSIST_DIR)

# List all collections
collections = client.list_collections()

# Print collection names
print("📚 Collections in ChromaDB:")
for col in collections:
    print(f"🔸 {col.name}")
# Out:
# 📚 Collections in ChromaDB:
# 🔸 user_a9061205-42ca-4055-9abb-24996f3d30a3
# 🔸 legal_index
# 🔸 user_9999
